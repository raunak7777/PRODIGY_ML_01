# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as mp

# %%
df = pd.read_csv('Housing.csv')

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
df.shape
# Out:
# (545, 13)

# %%
df.drop(columns=['stories','mainroad','guestroom','basement','hotwaterheating','airconditioning','parking','prefarea','furnishingstatus'], inplace=True)

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms
# 0  13300000  7420         4          2
# 1  12250000  8960         4          4
# 2  12250000  9960         3          2
# 3  12215000  7500         4          2
# 4  11410000  7420         4          1

# %%
missing_data = df.isnull().sum()
print(missing_data)
# Out:
# price        0
# area         0
# bedrooms     0
# bathrooms    0
# dtype: int64

# %%
print(sns.lineplot(x=df['price'],y=df['area']))
# Out:
# AxesSubplot(0.125,0.11;0.775x0.77)

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
from sklearn.model_selection import train_test_split

X=df.drop('price',axis=1)
y=df['price']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression().fit(X_train,y_train)
predictions=model.predict(X_test)

# %%
area = 7200
bathroom = 2
bedroom = 3

predicted_price = model.predict([[area, bathroom, bedroom]])

print("Predicted Price:", predicted_price[0])
# Out:
# Predicted Price: 7575490.30102783
# C:\Users\My PC\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
